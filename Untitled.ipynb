# %%
import requests
#url = 'https://developer.nrel.gov/api/solar/solar_resource/v1.json?api_key=IEemIofJMzp17AK0WJ4HPQoRhleujzX6tN5i50Kn&lat=40&lon=-105'
url = 'https://developer.nrel.gov/api/alt-fuel-stations/v1.json?fuel_type=E85,ELEC&state=TX&limit=2&api_key=itZbUBbYe9J5TTQUUHink0a6ux4NKeWaEtffSw4a'
response = requests.get(url)
city_data = response.json()
print(url)
# Out:
# https://developer.nrel.gov/api/alt-fuel-stations/v1.json?fuel_type=E85,ELEC&state=TX&limit=2&api_key=itZbUBbYe9J5TTQUUHink0a6ux4NKeWaEtffSw4a

# %%
cities = city_data [1]
for city in cities:
    print('city: {} {}'.format(city['name'], country['iso2Code']))

# %%
import numpy as np
import pandas as pd
import requests
result=requests.get ('https://developer.nrel.gov/api/alt-fuel-stations/v1/nearest.json?api_key=IEemIofJMzp17AK0WJ4HPQoRhleujzX6tN5i50Kn&location=Houston,TX')

# %%
result.status_code
# Out:
# 200

# %%
result.text
# Out:
# '{"latitude":29.760803,"longitude":-95.369506,"location_country":"US","precision":{"value":4,"name":"locality","types":["locality","political"]},"station_locator_url":"http://www.afdc.energy.gov/afdc/locator/stations/","total_results":82,"station_counts":{"total":261,"fuels":{"BD":{"total":2},"E85":{"total":2},"ELEC":{"total":256,"stations":{"total":77}},"HY":{"total":0},"LNG":{"total":0},"CNG":{"total":1},"LPG":{"total":0}}},"offset":0,"fuel_stations":[{"access_code":"public","access_days_time":"MON: 24 hours | TUE: 24 hours | WED: 24 hours | THU: 24 hours | FRI: 24 hours | SAT: 24 hours | SUN: 24 hours","access_detail_code":null,"cards_accepted":null,"date_last_confirmed":"2020-04-21","expected_date":null,"fuel_type_code":"ELEC","groups_with_access_code":"Public","id":154525,"open_date":null,"owner_type_code":null,"status_code":"E","station_name":"Houston City Hall-- (Walker Street Parking)","station_phone":"888-998-2546","updated_at":"2020-04-21T08:08:08Z","facility_type":null,"ge
# ...

# %%
result.json()
# Out:
# {'latitude': 29.760803,
#  'longitude': -95.369506,
#  'location_country': 'US',
#  'precision': {'value': 4,
#   'name': 'locality',
#   'types': ['locality', 'political']},
#  'station_locator_url': 'http://www.afdc.energy.gov/afdc/locator/stations/',
#  'total_results': 82,
#  'station_counts': {'total': 261,
#   'fuels': {'BD': {'total': 2},
#    'E85': {'total': 2},
#    'ELEC': {'total': 256, 'stations': {'total': 77}},
#    'HY': {'total': 0},
#    'LNG': {'total': 0},
#    'CNG': {'total': 1},
#    'LPG': {'total': 0}}},
#  'offset': 0,
#  'fuel_stations': [{'access_code': 'public',
#    'access_days_time': 'MON: 24 hours | TUE: 24 hours | WED: 24 hours | THU: 24 hours | FRI: 24 hours | SAT: 24 hours | SUN: 24 hours',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-21',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 154525,
#    'open_date': None,
# ...
